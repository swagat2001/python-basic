# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
visa_df = pd.read_csv('C:\\Users\\swaga\\OneDrive\\Documents\\datafiles\\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_df = pd.read_csv('C:\\Users\\swaga\\OneDrive\\Documents\\datafiles\\bank.csv',sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **mehods apply on visa_df**
#
# - shape
#
#
# - size
#
#
# - len
#
#
# - columns
#
#
# - head
#
#
# - tail
#
#
# - isnull
#
#
# - dtypes
#
#
# - info

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.size
# Out:
# 305760

# %%
len(visa_df)
# Out:
# 25480

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.isnull().count()
# Out:
# case_id                  25480
# continent                25480
# education_of_employee    25480
# has_job_experience       25480
# requires_job_training    25480
# no_of_employees          25480
# yr_of_estab              25480
# region_of_employment     25480
# prevailing_wage          25480
# unit_of_wage             25480
# full_time_position       25480
# case_status              25480
# dtype: int64

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
data_types = visa_df.dtypes

# %%
type(data_types)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - series type has without column names
#
#
# - we can directly apply math operations
#
#
# - series is a kind of dictionary means keys and values (key-value pair)

# %%
data_types.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data_types.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
d2 = pd.DataFrame(zip(data_types.keys(),data_types.values))
d2
# Out:
#                         0        1
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
keys = data_types.keys()
values = data_types.values
cols = ['keys','values']
data_types_df = pd.DataFrame(zip(keys,values),columns = cols)
data_types_df
# Out:
#                      keys   values
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
data_types_df.to_csv('data_types_df.csv',index = False)

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
dtd = pd.read_csv('data_types_df.csv')

# %%
dtd
# Out:
#                      keys   values
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %% [markdown]
# **Task-2**
#
# - I want to separate categorical and numerical columns

# %%
# idea
# make two empty list cat_list,num_list
# iterate the data_types.items
# if value == int or float then key should go to numlist

cat_list = []
num_list = []

for col, dtype in dtd.dtypes.items():
    if dtype == 'int64' or dtype == 'float64':
        num_list.append(col)
    else:
        cat_list.append(col)

# %%
for key,value in zip(keys,values):
    print(key,value)
    if value == 'object':
        cat_list.append(key)
    else:
        num_list.append(key)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
for value in dict(data_types).items():
    if value == 'object':
        cat_list.append(key)
    else:
        num_list.append(key)

# %%
cat_list,num_list
# Out:
# (['keys',
#   'values',
#   'case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees',
#   'yr_of_estab',
#   'prevailing_wage',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status',
#   'case_status'])

# %%
cat_list = [key for key, value in data_types.items() if value == 'object']
num_list = [key for key, value in data_types.items() if value != 'object']

# %%
cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# **select_dtypes**

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **selection of data**
#
# we can select the data using the below:
#
#
# - take
#
#
# - loc
#
#
# - iloc

# %%
# select 100,200,300
# select continent,previliging_wage,case_status
visa_df.take([100,200,300],axis =0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
cols = [1,8,11]
visa_df.take(cols,axis =1)
# Out:
#       continent  prevailing_wage case_status
# 0          Asia         592.2029      Denied
# 1          Asia       83425.6500   Certified
# 2          Asia      122996.8600      Denied
# 3          Asia       83434.0300      Denied
# 4        Africa      149907.3900   Certified
# ...         ...              ...         ...
# 25475      Asia       77092.5700   Certified
# 25476      Asia      279174.7900   Certified
# 25477      Asia      146298.8500   Certified
# 25478      Asia       86154.7700   Certified
# 25479      Asia       70876.9100   Certified
#
# [25480 rows x 3 columns]

# %%
cols = [1,8,11]
visa_df.take(cols,axis =1).take([100,200,300],axis =0)
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
cols = [1,8,11]
visa_df.take(cols,axis =1).take([90:93],axis =0)
# Out:
#   File "C:\Users\swaga\AppData\Local\Temp\ipykernel_719228\111658105.py", line 2
#     visa_df.take(cols,axis =1).take([90:93],axis =0)
#                                        ^
# SyntaxError: invalid syntax

# %%
l1 = range(2,5)
l2 = [2,3,4,5]
# l3 = [2:5]
visa_df.take(l1,axis =0)
visa_df.take(l2,axis =0)
# visa_df.take(l3,axis =0)
# visa_df.take(5,axis =0)

# %% [markdown]
# - drawbacks at a time either we ca select rows or columns
#
#
#
# **iloc**

# %%
cols = [1,8,11]
rows = [100,200,300]
visa_df.iloc[rows,cols]

# %%
# cols = [1,8,11]
# rows = [100,200,300]
visa_df.iloc[[100,200,300],[1,8,11]]

# %%
visa_df.iloc[[100,200,300]]

# %%
visa_df.iloc[[1,8,11]]

# %%
visa_df.iloc[[100:105],[1,8,11]]

# %%
visa_df.iloc[[100,200,300],[1:4]]

# %%
visa_df.iloc[range(1,5),range(1,3)]

# %%
visa_df.iloc[100]

# %%
visa_df.iloc[[100,200,300],['continent']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_719228\4281766789.py in <module>
# ----> 1 visa_df.iloc[[100,200,300],['continent']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1459     def _getitem_tuple(self, tup: tuple):
#    1460
# -> 1461         tup = self._validate_tuple_indexer(tup)
#    1462         with suppress(IndexingError):
#    1463             return self._getitem_lowerdim(tup)
#
# ...

# %%
visa_df.loc[[100,200,300],['continent']]
# Out:
#     continent
# 100      Asia
# 200      Asia
# 300      Asia

# %% [markdown]
# **How to select the columns**

# %%
# always whenever you open the new notebook
# step-1: import the packages 
# step-2: Read the data

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df[['continent']].head()
# Out:
#   continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4    Africa

# %%
visa_df[['continent','case_status']]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
visa_df.loc['continent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_719228\1932338026.py in <module>
# ----> 1 visa_df.loc['continent']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
#    1204         self._validate_key(key, axis)
# -> 1205         return self._get_label(key, axis=axis)
#    1206
#    1207     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
visa_df.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]
