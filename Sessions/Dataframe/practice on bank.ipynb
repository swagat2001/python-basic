# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

bank_df = pd.read_csv('C:\\Users\\swaga\\OneDrive\\Documents\\datafiles\\bank.csv',sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
cat = visa_df.select_dtypes(include='object').columns
num = visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
bank_df['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
bank_df['job'].nunique()
# Out:
# 12

# %%
# step-1
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
# step-2
bank_df['job']
# Out:
# 0          unemployed
# 1            services
# 2          management
# 3          management
# 4         blue-collar
#             ...
# 4516         services
# 4517    self-employed
# 4518       technician
# 4519      blue-collar
# 4520     entrepreneur
# Name: job, Length: 4521, dtype: object

# %%
# step-3: equating a specific level
con = bank_df['job'] == 'unemployed'
con
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# Name: job, Length: 4521, dtype: bool

# %%
# step-4: pass the true condition to the entire dataframe
bank_df[con]
# Out:
#       age         job   marital  education default  balance housing loan  \
# 0      30  unemployed   married    primary      no     1787      no   no
# 79     40  unemployed   married  secondary      no      219     yes   no
# 99     31  unemployed    single    primary      no      406      no   no
# 108    56  unemployed   married    primary      no     3391      no   no
# 126    24  unemployed    single  secondary      no      119      no   no
# ...   ...         ...       ...        ...     ...      ...     ...  ...
# 4417   33  unemployed   married   tertiary      no      302     yes  yes
# 4448   44  unemployed   married  secondary      no      304     yes   no
# 4467   43  unemployed  divorced  secondary      no     1577     yes   no
# 4488   31  unemployed    single  secondary      no      315      no   no
# 4506   42  unemployed  divorced   tertiary      no     -166      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   19   oct        79         1     -1         0  unknown   no
# 79    cellular   17   nov       204         2    196         1  failure   no
# 99    cellular    4   feb       736         1     -1         0  unknown  yes
# 108   cellular   21   apr       243         1     -1         0  unknown  yes
# 126    unknown   15   sep        51         1     -1         0  unknown   no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4417  cellular   16   apr       670         1     -1         0  unknown   no
# 4448   unknown   12   may       129         2     -1         0  unknown   no
# 4467  cellular   19   nov        87         1     -1         0  unknown   no
# 4488  cellular   30   jan       130         1      2         1    other   no
# 4506  cellular   29   aug        85         4     -1         0  unknown   no
#
# [128 rows x 17 columns]

# %%
len(bank_df[con])
# Out:
# 128

# %%
countt =[]
for col in cat:
    labels = bank_df[col].unique()
    print(labels)
    for i in labels:
        con = bank_df[col] == i
        summ =len(bank_df[con])
        countt.append(summ)
        print(countt)
    df = pd.DataFrame(zip(labels,count),columns = ['column','count'])
    df.to_csv(f'{col}_df.csv',index=False)
# Out:
# ['unemployed' 'services' 'management' 'blue-collar' 'self-employed'
#  'technician' 'entrepreneur' 'admin.' 'student' 'housemaid' 'retired'
#  'unknown']
# [128]
# [128, 417]
# [128, 417, 969]
# [128, 417, 969, 946]
# [128, 417, 969, 946, 183]
# [128, 417, 969, 946, 183, 768]
# [128, 417, 969, 946, 183, 768, 168]
# [128, 417, 969, 946, 183, 768, 168, 478]
# [128, 417, 969, 946, 183, 768, 168, 478, 84]
# [128, 417, 969, 946, 183, 768, 168, 478, 84, 112]
# [128, 417, 969, 946, 183, 768, 168, 478, 84, 112, 230]
# [128, 417, 969, 946, 183, 768, 168, 478, 84, 112, 230, 38]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36188\112408404.py in <module>
#       8         countt.append(summ)
#       9         print(countt)
# ---> 10     df = pd.DataFrame(zip(labels,count),columns = ['column','count'])
#      11     df.to_csv(f'{col}_df.csv',index=False)
#
# NameError: name 'count' is not defined
