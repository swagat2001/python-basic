# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

visa_df = pd.read_csv('C:\\Users\\swaga\\OneDrive\\Documents\\datafiles\\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat = visa_df.select_dtypes(include='object').columns
num = visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %% [markdown]
# **unique**

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df['continent'].unique())
# Out:
# 6

# %% [markdown]
# **nunique**

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# **Frequency tables**
#
#
# - continent column has some unique continent names are available
#
#
# - total data size 25480 observation
#
#
# - will create a table having continents and number of applications from each continent

# %%
# step-1: total data
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
# step-2: select particular column
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
# step-3: equating a specific label
con = visa_df['continent'] == 'Asia'
con
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
# step-4: pass the true condition to the entire dataframe
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 5                         N             2339         2012
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 5                    South       78252.1400         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 5       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [16861 rows x 12 columns]

# %%
len(visa_df[con])
# Out:
# 16861

# %%
no_of_application=[]
labels = visa_df['continent'].unique()
for i in labels:
    con = visa_df['continent'] == i
    countt = len(visa_df[con])
    no_of_application.append(countt)

# %%
no_of_application
# Out:
# [16861, 551, 3292, 3732, 852, 192]

# %%
continent_df = pd.DataFrame(zip(labels,no_of_application),
                 columns = ['Continent','No applicants'])
continent_df
# Out:
#        Continent  No applicants
# 0           Asia          16861
# 1         Africa            551
# 2  North America           3292
# 3         Europe           3732
# 4  South America            852
# 5        Oceania            192

# %%
continent_df.to_csv('continent.csv',index=False)

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
countt =[]
for col in cat[1:]:
    labels = visa_df[col].unique()
    print(labels)
    for i in labels:
        con = visa_df[col] == i
        summ =len(visa_df[con])
        countt.append(summ)
        print(countt)
    df = pd.DataFrame(zip(labels,countt),columns = ['column','count'])
    df.to_csv(f'{col}_df.csv',index=False)
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania']
# [16861]
# [16861, 551]
# [16861, 551, 3292]
# [16861, 551, 3292, 3732]
# [16861, 551, 3292, 3732, 852]
# [16861, 551, 3292, 3732, 852, 192]
# ['High School' "Master's" "Bachelor's" 'Doctorate']
# [16861, 551, 3292, 3732, 852, 192, 3420]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192]
# ['N' 'Y']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802]
# ['N' 'Y']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955]
# ['West' 'Northeast' 'South' 'Midwest' 'Island']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375]
# ['Hour' 'Year' 'Week' 'Month']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272, 89]
# ['Y' 'N']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272, 89, 22773]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272, 89, 22773, 2707]
# ['Denied' 'Certified']
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272, 89, 22773, 2707, 8462]
# [16861, 551, 3292, 3732, 852, 192, 3420, 9634, 10234, 2192, 10678, 14802, 22525, 2955, 6586, 7195, 7017, 4307, 375, 2157, 22962, 272, 89, 22773, 2707, 8462, 17018]

# %% [markdown]
# **Value_counts**

# %%
continent_vc = visa_df['continent'].value_counts()
continent_vc
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
for col in cat[1:]:
    counts = visa_df[col].value_counts()
    
    df = counts.reset_index()
    df.columns = ['column', 'count']
    
    df.to_csv(f'{col}2_df.csv', index=False)

# %%
pd.read_csv('continent2_df.csv')
# Out:
#           column  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
keys = continent_vc.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
values = continent_vc.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
continent_df = pd.DataFrame(zip(keys,values),
                           columns = ['continent','number_of-applicants'])

continent_df.to_csv('continent_df.csv',index=False)

# %%
pd.read_csv('continent_df.csv')
# Out:
#        continent  number_of-applicants
# 0           Asia                 16861
# 1         Europe                  3732
# 2  North America                  3292
# 3  South America                   852
# 4         Africa                   551
# 5        Oceania                   192

# %%
directory = r'C:\Users\swaga\OneDrive\Documents\frequency_table'
for i in cat[1:]:
    vc = visa_df[i].value_counts()
    keys = vc.keys()
    values = vc.values
    df = pd.DataFrame(zip(keys,values),columns = ['{i}','count'])
    df.to_csv(f'{i}_df.csv',index=False)

# %%
len(cat)
# Out:
# 9

# %% [markdown]
# - step-1 : create a folder i.e frequency table
#
#
# - step-2: get the directory path
#
#     - new_directory = python_location + folder_name
#
#
# - step-3: get thr full path
#
#     - new_directory + column.csv

# %% [markdown]
# **Step-1: Create a folder**

# %%
import os
folder_name =  'freq_tables'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'freq_tables'

# %% [markdown]
# **Step-2: new_directory**

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\swaga\\NareshIT\\Sessions\\Dataframe'

# %%
nwd = os.path.join(cwd,folder_name)
nwd
# Out:
# 'C:\\Users\\swaga\\NareshIT\\Sessions\\Dataframe\\freq_tables'

# %% [markdown]
# **Step-3: full path**

# %%
for i in cat[1:]:
    file_name = f'{i}_df.csv'
    path = os.path.join(nwd,file_name)
    print(path)
# Out:
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\continent_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\education_of_employee_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\has_job_experience_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\requires_job_training_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\region_of_employment_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\unit_of_wage_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\full_time_position_df.csv
# C:\Users\swaga\NareshIT\Sessions\Dataframe\freq_tables\case_status_df.csv

# %% [markdown]
# **groupBy**
#
# - in SQL we have a group by option is there
#
#
# - similarly in python also we have group by
#
#
# - first it will group the simillar labeles tgether
#
#
# - on that we can perform any math operations

# %%
visa_df.groupby('continent')

# %%
list(visa_df.groupby('continent'))
# Out:
# [('Africa',
#            case_id continent education_of_employee has_job_experience  \
#   4         EZYV05    Africa              Master's                  Y
#   18        EZYV19    Africa              Master's                  Y
#   74        EZYV75    Africa              Master's                  Y
#   194      EZYV195    Africa              Master's                  Y
#   242      EZYV243    Africa            Bachelor's                  N
#   ...          ...       ...                   ...                ...
#   25385  EZYV25386    Africa             Doctorate                  Y
#   25408  EZYV25409    Africa              Master's                  Y
#   25443  EZYV25444    Africa            Bachelor's                  N
#   25446  EZYV25447    Africa              Master's                  N
#   25474  EZYV25475    Africa             Doctorate                  N
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   4                         N             1082         2005
#   18                        N             4743         2004
#   74                        N             3705         2001
#   194                       N             2180         1992
#   242                       Y             2509         2003
#   ...                     ...              ...          ...
#   25385                     N             2513         1975
#   25408                     Y             1671         1992
#   25443                     N            72892         2007
#   25446                     Y             2024         1971
#   25474                     N             2594         1979
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   4                    South        149907.39         Year                  Y
#   18                 Midwest        150441.13         Year                  Y
#   74                   South         47170.76         Year                  Y
#   194                Midwest        113637.40         Year                  Y
#   242                   West         51886.04         Year                  Y
#   ...                    ...              ...          ...                ...
#   25385                 West         76348.20         Year                  Y
#   25408              Midwest         55756.35         Year                  Y
#   25443            Northeast           215.10         Hour                  Y
#   25446                South         42353.45         Year                  Y
#   25474            Northeast         51104.78         Year                  Y
#
#         case_status
#   4       Certified
#   18      Certified
#   74      Certified
#   194     Certified
#   242        Denied
#   ...           ...
#   25385   Certified
#   25408   Certified
#   25443   Certified
#   25446   Certified
#   25474   Certified
#
#   [551 rows x 12 columns]),
#  ('Asia',
#            case_id continent education_of_employee has_job_experience  \
#   0         EZYV01      Asia           High School                  N
#   1         EZYV02      Asia              Master's                  Y
#   2         EZYV03      Asia            Bachelor's                  N
#   3         EZYV04      Asia            Bachelor's                  N
#   5         EZYV06      Asia              Master's                  Y
#   ...          ...       ...                   ...                ...
#   25475  EZYV25476      Asia            Bachelor's                  Y
#   25476  EZYV25477      Asia           High School                  Y
#   25477  EZYV25478      Asia              Master's                  Y
#   25478  EZYV25479      Asia              Master's                  Y
#   25479  EZYV25480      Asia            Bachelor's                  Y
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   0                         N            14513         2007
#   1                         N             2412         2002
#   2                         Y            44444         2008
#   3                         N               98         1897
#   5                         N             2339         2012
#   ...                     ...              ...          ...
#   25475                     Y             2601         2008
#   25476                     N             3274         2006
#   25477                     N             1121         1910
#   25478                     Y             1918         1887
#   25479                     N             3195         1960
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   0                     West         592.2029         Hour                  Y
#   1                Northeast       83425.6500         Year                  Y
#   2                     West      122996.8600         Year                  Y
#   3                     West       83434.0300         Year                  Y
#   5                    South       78252.1400         Year                  Y
#   ...                    ...              ...          ...                ...
#   25475                South       77092.5700         Year                  Y
#   25476            Northeast      279174.7900         Year                  Y
#   25477                South      146298.8500         Year                  N
#   25478                 West       86154.7700         Year                  Y
#   25479              Midwest       70876.9100         Year                  Y
#
#         case_status
#   0          Denied
#   1       Certified
#   2          Denied
#   3          Denied
#   5       Certified
#   ...           ...
#   25475   Certified
#   25476   Certified
#   25477   Certified
#   25478   Certified
#   25479   Certified
#
#   [16861 rows x 12 columns]),
#  ('Europe',
#            case_id continent education_of_employee has_job_experience  \
#   9         EZYV10    Europe             Doctorate                  Y
#   16        EZYV17    Europe              Master's                  Y
#   24        EZYV25    Europe             Doctorate                  Y
#   36        EZYV37    Europe           High School                  Y
#   37        EZYV38    Europe              Master's                  Y
#   ...          ...       ...                   ...                ...
#   25435  EZYV25436    Europe            Bachelor's                  N
#   25448  EZYV25449    Europe             Doctorate                  Y
#   25460  EZYV25461    Europe              Master's                  Y
#   25462  EZYV25463    Europe            Bachelor's                  N
#   25466  EZYV25467    Europe            Bachelor's                  Y
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   9                         N             2251         1995
#   16                        N            76638         1991
#   24                        N              241         1981
#   36                        N             2520         1981
#   37                        Y               44         1965
#   ...                     ...              ...          ...
#   25435                     N             1606         1998
#   25448                     N             4119         1971
#   25460                     Y              413         1997
#   25462                     Y             1715         2004
#   25466                     N             1938         2005
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   9                    South         67514.76         Year                  Y
#   16                 Midwest          3706.79         Year                  Y
#   24                 Midwest         71286.04         Year                  Y
#   36                    West          2490.12         Year                  Y
#   37                   South        110817.26         Year                  Y
#   ...                    ...              ...          ...                ...
#   25435                South        126329.96         Year                  Y
#   25448                 West         86894.10         Year                  Y
#   25460                 West          8263.47         Year                  Y
#   25462                 West        166032.62         Year                  Y
#   25466                 West          6973.40         Year                  Y
#
#         case_status
#   9       Certified
#   16      Certified
#   24      Certified
#   36         Denied
#   37      Certified
#   ...           ...
#   25435   Certified
#   25448   Certified
#   25460   Certified
#   25462      Denied
#   25466      Denied
#
#   [3732 rows x 12 columns]),
#  ('North America',
#            case_id      continent education_of_employee has_job_experience  \
#   7         EZYV08  North America            Bachelor's                  Y
#   21        EZYV22  North America              Master's                  Y
#   23        EZYV24  North America           High School                  N
#   25        EZYV26  North America              Master's                  N
#   43        EZYV44  North America              Master's                  Y
#   ...          ...            ...                   ...                ...
#   25451  EZYV25452  North America           High School                  Y
#   25465  EZYV25466  North America           High School                  N
#   25467  EZYV25468  North America              Master's                  N
#   25469  EZYV25470  North America              Master's                  Y
#   25470  EZYV25471  North America              Master's                  Y
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   7                         N             3035         1924
#   21                        N             1706         2013
#   23                        N             1517         1884
#   25                        N             1100         1997
#   43                        N             2582         1989
#   ...                     ...              ...          ...
#   25451                     N               97         2013
#   25465                     N             2577         1995
#   25467                     Y             2504         1882
#   25469                     N             2261         1997
#   25470                     N             2272         1970
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   7                     West         418.2298         Hour                  Y
#   21                 Midwest      137694.9800         Year                  N
#   23                 Midwest       90108.3800         Year                  N
#   25                 Midwest       99489.6500         Year                  Y
#   43                   South       54614.4200         Year                  Y
#   ...                    ...              ...          ...                ...
#   25451            Northeast      111518.5900         Year                  N
#   25465                South         481.2238         Hour                  Y
#   25467            Northeast      105900.6600         Year                  Y
#   25469            Northeast      273772.4700         Year                  N
#   25470            Northeast         516.4101         Hour                  Y
#
#         case_status
#   7          Denied
#   21      Certified
#   23      Certified
#   25      Certified
#   43      Certified
#   ...           ...
#   25451      Denied
#   25465   Certified
#   25467   Certified
#   25469   Certified
#   25470   Certified
#
#   [3292 rows x 12 columns]),
#  ('Oceania',
#            case_id continent education_of_employee has_job_experience  \
#   241      EZYV242   Oceania             Doctorate                  Y
#   288      EZYV289   Oceania            Bachelor's                  N
#   708      EZYV709   Oceania            Bachelor's                  N
#   955      EZYV956   Oceania              Master's                  N
#   960      EZYV961   Oceania            Bachelor's                  N
#   ...          ...       ...                   ...                ...
#   24865  EZYV24866   Oceania             Doctorate                  N
#   25150  EZYV25151   Oceania              Master's                  Y
#   25196  EZYV25197   Oceania            Bachelor's                  Y
#   25404  EZYV25405   Oceania             Doctorate                  Y
#   25405  EZYV25406   Oceania              Master's                  Y
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   241                       N             2871         2009
#   288                       N             2288         2011
#   708                       N             3227         1928
#   955                       N            17541         1986
#   960                       N              363         2013
#   ...                     ...              ...          ...
#   24865                     Y             3487         1930
#   25150                     N             1076         1869
#   25196                     N              385         2000
#   25404                     N              429         2006
#   25405                     N             1829         1993
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   241                  South         56606.54        Month                  Y
#   288                   West         82385.60         Year                  Y
#   708                Midwest         92422.74         Year                  Y
#   955              Northeast         75224.53         Year                  Y
#   960              Northeast         97469.69         Year                  Y
#   ...                    ...              ...          ...                ...
#   24865                 West         59969.55         Year                  Y
#   25150            Northeast         87467.12         Year                  N
#   25196                South         94420.47         Year                  Y
#   25404                 West         27819.35         Year                  Y
#   25405            Northeast         74975.25         Year                  Y
#
#         case_status
#   241     Certified
#   288        Denied
#   708     Certified
#   955        Denied
#   960        Denied
#   ...           ...
#   24865      Denied
#   25150   Certified
#   25196   Certified
#   25404   Certified
#   25405   Certified
#
#   [192 rows x 12 columns]),
#  ('South America',
#            case_id      continent education_of_employee has_job_experience  \
#   121      EZYV122  South America            Bachelor's                  N
#   130      EZYV131  South America           High School                  N
#   171      EZYV172  South America            Bachelor's                  Y
#   188      EZYV189  South America              Master's                  Y
#   224      EZYV225  South America            Bachelor's                  N
#   ...          ...            ...                   ...                ...
#   25319  EZYV25320  South America              Master's                  Y
#   25364  EZYV25365  South America            Bachelor's                  Y
#   25413  EZYV25414  South America              Master's                  Y
#   25444  EZYV25445  South America              Master's                  Y
#   25455  EZYV25456  South America            Bachelor's                  N
#
#         requires_job_training  no_of_employees  yr_of_estab  \
#   121                       N             1415         1913
#   130                       N             2554         2005
#   171                       N             5461         1979
#   188                       N             1551         1989
#   224                       N             1004         1960
#   ...                     ...              ...          ...
#   25319                     N             1186         2004
#   25364                     N             1269         2000
#   25413                     N             2423         2005
#   25444                     N             1081         1838
#   25455                     N            24335         1993
#
#         region_of_employment  prevailing_wage unit_of_wage full_time_position  \
#   121              Northeast        53114.020         Year                  Y
#   130                Midwest       247393.010         Year                  Y
#   171              Northeast         9078.620         Year                  Y
#   188                   West          630.660         Year                  Y
#   224                Midwest       135792.520         Year                  Y
#   ...                    ...              ...          ...                ...
#   25319                 West        75773.380         Year                  Y
#   25364                South         5769.540         Year                  Y
#   25413              Midwest       163067.990         Year                  Y
#   25444            Northeast          156.607         Hour                  Y
#   25455              Midwest        97393.490         Year                  Y
#
#         case_status
#   121        Denied
#   130     Certified
#   171     Certified
#   188     Certified
#   224     Certified
#   ...           ...
#   25319      Denied
#   25364   Certified
#   25413   Certified
#   25444   Certified
#   25455   Certified
#
#   [852 rows x 12 columns])]

# %%
visa_df.groupby('continent').size()
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# dtype: int64

# %%
visa_df['continent'].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %% [markdown]
# **Bar Charts**
#
# - bar charts under the matplotlib
#
#
# - plt.bar
#
#
# - bar chart needs class names and class frequency
#
#
# - class names we can get from value counts
#
#
# - class frequency we can get from value counts

# %%
continent_vc = visa_df['continent'].value_counts()
continent_vc
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
keys = continent_vc.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
values = continent_vc.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
plt.figure(figsize=(10,5))
colors = ['Red','Green','Yellow','Orange','Blue','cyan']
plt.bar(keys,values,color = colors)
plt.xlabel('class names')
plt.ylabel('class frequency')
plt.title('continent_BarChart')
plt.savefig('continent_BarChart.jpg')
plt.show()

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in cat[1:]:
    vc = visa_df[i].value_counts()
    keys = vc.keys()
    values = vc.values
    plt.figure(figsize=(10,5))
    plt.bar(keys,values,color = colors)
    plt.xlabel('class names')
    plt.ylabel('class frequency')
    plt.title(f'{i}_BarChart')
    plt.savefig(f'{i}_BarChart.jpg')
    plt.show()

# %%
# task to save all the plot in a folder
import os
folder_name = 'Barchart_cat'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
    
cwd = os.getcwd()
cwd

nwd = os.path.join(cwd,folder_name)
nwd

for i in cat[1:]:
    vc = visa_df[i].value_counts()
    keys = vc.keys()
    values = vc.values
    plt.figure(figsize=(10,5))
    colors = ['Red','Green','Yellow','Orange','Blue','cyan']
    plt.bar(keys,values,color = colors)
    plt.xlabel('class names')
    plt.ylabel('class frequency')
    plt.title(f'{i}_BarChart')
    file_name = f'{i}_BarChart.jpg'
    path = os.path.join(nwd,file_name)
    plt.savefig(path)
    print(path)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'Barchart_cat'
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\continent_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\education_of_employee_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\has_job_experience_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\requires_job_training_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\region_of_employment_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\unit_of_wage_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\full_time_position_BarChart.jpg
# C:\Users\swaga\NareshIT\Sessions\Dataframe\Barchart_cat\case_status_BarChart.jpg

# %%
for i in cat[1:]:
    vc = visa_df[i].value_counts()
    keys = vc.keys()
    values = vc.values
    plt.figure(figsize=(10,5))
    plt.bar(keys,values,color = colors)
    plt.xlabel('class names')
    plt.ylabel('class frequency')
    plt.title(f'{i}_BarChart')
    plt.savefig(f'{i}_BarChart.jpg')
    plt.show()

# %% [markdown]
# **Subplots**

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)
# Out:
# <AxesSubplot:>

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
plt.figure(figsize=(15,15))
for i in range(1,len(cat)):
    vc = visa_df[cat[i]].value_counts()
    keys = vc.keys()
    values = vc.values
    
    plt.subplot(3,3,i)
    
    plt.bar(keys,values,color = colors)
    plt.xlabel('class names')
    plt.ylabel('class frequency')
    plt.title(f'{cat[i]}_BarChart')
    plt.savefig(f'{cat[i]}_BarChart.jpg')
#     plt.show()

# %% [markdown]
# **piechart**

# %%
continent_vc = visa_df['continent'].value_counts()
continent_vc

keys = continent_vc.keys()
keys

values = continent_vc.values
values

plt.pie(x=values,
       labels=keys,
       autopct="%0.1f%%",
       startangle=90,
       explode=[0.1,0.2,0.3,0.1,0.5,0.1])
plt.show()
